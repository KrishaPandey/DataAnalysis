# %%
# Importing The lIbraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# loading the dataset
df=sns.load_dataset("mpg")

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.drop(["name"],axis=1,inplace=True)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0          70    usa
# 1          70    usa
# 2          70    usa
# 3          70    usa
# 4          70    usa

# %%
# summary of dataset
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
#  **DataPreprocessing**
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin
# 32           71     usa
# 126          74     usa
# 330          80  europe
# 336          80     usa
# 354          81  europe
# 374          82     usa

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
#  univariate analysis
df["cylinders"].unique()
# Out:
# array([8, 4, 6, 3, 5])

# %%
df.cylinders.value_counts()
# Out:
# cylinders
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.countplot( x="cylinders", data=df, palette="cubehelix")
plt.show()

# %%
df.model_year.value_counts()
# Out:
# model_year
# 73    40
# 78    36
# 76    34
# 75    30
# 82    30
# 70    29
# 79    29
# 72    28
# 77    28
# 81    28
# 71    27
# 80    27
# 74    26
# Name: count, dtype: int64

# %%
df["model_year"]=(1900+df.model_year)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0        1970    usa
# 1        1970    usa
# 2        1970    usa
# 3        1970    usa
# 4        1970    usa

# %%
plt.figure(figsize=(15,8))
sns.countplot( x="model_year", data=df, palette="rainbow")
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="origin",data=df,palette="rainbow")
plt.show()

# %%
sns.displot(df["horsepower"])
plt.show()

# %%
sns.displot(df["displacement"])
plt.show()

# %%
# bivariate analysis
plt.figure(figsize=(15,8))
sns.boxplot(x="cylinders",y="mpg",data=df,palette="Spectral")
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg'>

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x="model_year",y="mpg",data=df,palette="Spectral")
# Out:
# <Axes: xlabel='model_year', ylabel='mpg'>

# %%
# multivariate analysis
graph=sns.lmplot(x="horsepower",y="mpg",hue="origin",data=df,palette="rainbow")
graph.set(xlim=(0,250))
graph.set(ylim=(0,50))
plt.show()

# %%
# multivariate analysis
graph=sns.lmplot(x="acceleration",y="mpg",hue="origin",data=df,palette="rainbow")
graph.set(ylim=(0,50))
graph.set(xlim=(5,28))
plt.show()

# %%
# HEATMAP OF correlation Matrix

# %%
plt. figure(figsize=(15,9))
sns.heatmap(df.corr(numeric_only=True), annot=True, linewidths=0.5, cmap='Spectral')
plt.show()

# %%
df.drop(["acceleration","displacement"],axis=1,inplace=True)

# %%
df.head()
# Out:
#     mpg  cylinders  horsepower  weight  model_year origin
# 0  18.0          8       130.0    3504        1970    usa
# 1  15.0          8       165.0    3693        1970    usa
# 2  18.0          8       150.0    3436        1970    usa
# 3  16.0          8       150.0    3433        1970    usa
# 4  17.0          8       140.0    3449        1970    usa

# %%
# feature engineering
from datetime import datetime

# %%
today=datetime.today()

# %%
today
# Out:
# datetime.datetime(2025, 2, 24, 11, 48, 27, 296031)

# %%
CURR_yEAR=today.year
CURR_yEAR
# Out:
# 2025

# %%
df["age"]=CURR_yEAR-df["model_year"]

# %%
df.age
# Out:
# 0      55
# 1      55
# 2      55
# 3      55
# 4      55
#        ..
# 393    43
# 394    43
# 395    43
# 396    43
# 397    43
# Name: age, Length: 392, dtype: int64

# %%
df.drop(["model_year"],axis=1,inplace=True)

# %%
df.head()
# Out:
#     mpg  cylinders  horsepower  weight origin  age
# 0  18.0          8       130.0    3504    usa   55
# 1  15.0          8       165.0    3693    usa   55
# 2  18.0          8       150.0    3436    usa   55
# 3  16.0          8       150.0    3433    usa   55
# 4  17.0          8       140.0    3449    usa   55

# %%
df.origin.unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
df=(pd.get_dummies(df,drop_first=True)).astype(int)

# %%
df
# Out:
#      mpg  cylinders  horsepower  weight  age  origin_japan  origin_usa
# 0     18          8         130    3504   55             0           1
# 1     15          8         165    3693   55             0           1
# 2     18          8         150    3436   55             0           1
# 3     16          8         150    3433   55             0           1
# 4     17          8         140    3449   55             0           1
# ..   ...        ...         ...     ...  ...           ...         ...
# 393   27          4          86    2790   43             0           1
# 394   44          4          52    2130   43             0           0
# 395   32          4          84    2295   43             0           1
# 396   28          4          79    2625   43             0           1
# 397   31          4          82    2720   43             0           1
#
# [392 rows x 7 columns]

# %%
# Modeling
x=df.drop(["mpg"],axis=1)
y=df["mpg"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42 )

# %%
x_train.shape
# Out:
# (313, 6)

# %%
y_train.shape
# Out:
# (313,)

# %%
 from sklearn.linear_model import LinearRegression

# %%
lr_model=LinearRegression()

# %%
lr_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
 lr_model.intercept_
 ##The value of y when all feature values (x) are 0.
# Out:
# 78.62376770393149

# %%
coeff_param=pd.DataFrame(lr_model.coef_,index=x.columns,columns=["Coefficient"])

# %%
coeff_param
# Out:
#               Coefficient
# cylinders        0.184897
# horsepower      -0.014568
# weight          -0.005695
# age             -0.742864
# origin_japan     0.396403
# origin_usa      -2.359528

# %%
y_pred=lr_model.predict(x_test)

# %%
y_pred
# Out:
# array([26.5199015 , 26.8557357 , 33.71997562, 24.73558325, 27.91862226,
#        29.99397962,  8.12344728, 30.11038786, 20.25780219, 29.38793944,
#        12.19197873, 25.46935274, 16.48317141, 29.15999524, 23.4608431 ,
#        28.94306942, 20.43753649, 32.59776313, 26.46084789, 30.41484995,
#        18.9980502 , 34.53220875, 34.77843495, 15.03657152, 29.32184659,
#        26.52400433, 21.7585812 , 16.14402993, 28.95895569, 24.58411677,
#        13.20179741, 22.8667678 , 21.21998619, 30.98924266, 11.50654688,
#        35.4789165 , 11.40415631, 24.3589092 , 11.87752588,  7.47105563,
#        13.13943976, 28.37951706, 35.06596057, 27.2423624 , 11.92226653,
#         9.01624059, 17.11099474, 32.0559546 , 23.65218184, 30.91193977,
#        11.74257949, 26.03066557, 22.68444454, 34.23329638, 27.65336   ,
#        17.20063417, 20.65395698, 22.1782271 , 23.59611599, 25.57255441,
#         7.64042573, 22.09292169, 26.14989548, 24.09789465, 29.13812063,
#        29.13998822, 25.31668439, 30.16907617, 22.06246077,  9.27916233,
#        22.1265893 , 13.21533383, 27.0273997 , 27.53851176, 23.71596333,
#        24.14249734, 13.75489767, 15.14955135, 25.48978461])

# %%
my_dict={"Actual":y_test,
         "Pred":y_pred }

# %%
compare=pd.DataFrame(my_dict)

# %%
compare.sample(10)
# Out:
#      Actual       Pred
# 307      26  26.149895
# 296      27  26.460848
# 349      34  34.778435
# 157      15  13.201797
# 270      21  29.138121
# 139      14  11.404156
# 115      15  13.754898
# 291      19  21.219986
# 257      19  22.866768
# 175      29  30.169076

# %%
##mean square error , mean absolute error, r2_score

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
def evaluation_metrics(actual,pred):
  MAE=mean_absolute_error(actual,pred)
  MSE=mean_squared_error(actual,pred)
  RMSE=np.sqrt(mean_squared_error(actual,pred))
  score=r2_score(actual,pred)
  return print(score,"\n",RMSE,"\n",MSE,"\n",MAE)

# %%
evaluation_metrics(y_test,y_pred)
# Out:
# 0.7791523053063809
#  3.3543812148708954
#  11.251873334678745
#  2.5034514729609167

# %%
#yellow brick library -for visualization

# %%
from yellowbrick.regressor import PredictionError,ResidualsPlot

# %%
visualizer=PredictionError(lr_model)
visualizer.fit(x_train,y_train)
visualizer.score(x_test,y_test)
visualizer.show()
# Out:
# <Axes: title={'center': 'Prediction Error for LinearRegression'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
visualizer=ResidualsPlot(lr_model)
visualizer.fit(x_train,y_train)
visualizer.score(x_test,y_test)
visualizer.show()
# Out:
# <Axes: title={'center': 'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>
